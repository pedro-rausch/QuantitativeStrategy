# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import yfinance as yf
from process_yf_data import ProcessYFData

# %%
# Preparing data
yf_data = ProcessYFData()
interval = ['2019-01-01', '2020-12-30']
data = yf.Ticker('SI=F').history(start=interval[0], end=interval[1])
df = yf_data.prep_data(data)

# Plotting
yf_data.visual(df[(df.index > interval[0]) & (df.index < interval[1])], interval)
